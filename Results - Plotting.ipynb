# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Emily exp - task 3 splits/Results.csv', index_col=0)

# %%
df = df.transpose()

# %%
df
# Out:
#         Random, length-based  Glove, length-based  Glove, cluster  \
# 9:1                   0.8510               0.8570          0.8630
# 8:1                   0.8509               0.8477          0.8594
# 7:1                   0.8478               0.8497          0.8556
# 6:1                   0.8415               0.8445          0.8458
# 5:1                   0.8358               0.8397          0.8388
# 4:1                   0.8337               0.8370          0.8414
# 3:1                   0.8253               0.8306          0.8329
# 2:1                   0.8149               0.8210          0.8221
# 1:1                   0.7825               0.7944          0.7934
# 0.5:1                 0.7501               0.7711          0.7681
# 0.25:1                0.7010               0.7328          0.7335
# 0.1:1                 0.6395               0.6916          0.7005
#
#         Pubmed from Glove, length-based  Pubmed from Glove, cluster  \
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-']

for i in range(len(df.columns)):
    col = df.columns[i]
    plt.plot(df.index, df[col], linestyle = line_styles[i], label = df.columns[i])
    
plt.title('\nTask 3:\nF1 score by train-test split ratio and stop-word selection method', fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_3_results.png", bbox_inches='tight');

# %%
df2 = pd.read_csv('./Emily exp - task 2 splits/Results.csv', index_col=0)

# %%
df2 = df2.transpose()

# %%
df2
# Out:
#         Random, length-based  Glove, length-based  Glove, cluster  \
# 9:1                   0.9284               0.9262          0.9421
# 8:1                   0.9272               0.9226          0.9308
# 7:1                   0.9212               0.9187          0.9274
# 6:1                   0.9181               0.9141          0.9197
# 5:1                   0.9095               0.9123          0.9172
# 4:1                   0.9032               0.9058          0.9145
# 3:1                   0.9010               0.9094          0.9135
# 2:1                   0.8911               0.9009          0.9050
# 1:1                   0.8590               0.8845          0.8976
# 0.5:1                 0.8170               0.8739          0.8842
# 0.25:1                0.7752               0.8616          0.8747
# 0.1:1                 0.7122               0.8424          0.8416
#
#         Pubmed from Glove, length-based  Pubmed from Glove, cluster  \
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-']

for i in range(len(df2.columns)):
    col = df2.columns[i]
    plt.plot(df2.index, df2[col], linestyle = line_styles[i], label = df2.columns[i])
    
plt.title('\nTask 2:\nF1 score by train-test split ratio and stop-word selection method', fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_2_results.png", bbox_inches='tight');

# %%
df3 = pd.read_csv('./Emily exp - task 3 imbalanced/Results.csv', index_col=0)

# %%
df3 = df3.transpose()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-']

for i in range(len(df3.columns)):
    col = df3.columns[i]
    plt.plot(df3.index, df3[col], linestyle = line_styles[i], label = df3.columns[i])
    
plt.title('\nTask 3:\nF1 score by positive:negative train ratio and stop-word selection method', fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_3_results_imbal.png", bbox_inches='tight');

# %%
df4 = pd.read_csv('./Emily exp - task 2 splits/Results_v2.csv', index_col=0)

# %%
df4 = df4.transpose()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-']

for i in range(len(df4.columns)):
    col = df4.columns[i]
    plt.plot(df4.index, df4[col], linestyle = line_styles[i], label = df4.columns[i])
    
plt.ylim([0.70, 0.975])
plt.title(
    '\nTask 2:\nF1 score by train-test split ratio and stop-word selection method\nNo symmetric triples', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_2_results_v2.png", bbox_inches='tight');

# %%
df5 = pd.read_csv('./Emily exp - Task 3 repeats/Results.csv', index_col=0)

# %%
df5 = df5.transpose()

# %%
df5
# Out:
#         Random, length-based  Glove, length-based  Glove, cluster  \
# 9:1                   0.8531               0.8565          0.8604
# 8:1                   0.8507               0.8535          0.8564
# 7:1                   0.8475               0.8500          0.8526
# 6:1                   0.8440               0.8478          0.8497
# 5:1                   0.8334               0.8421          0.8424
# 4:1                   0.8320               0.8368          0.8382
# 3:1                   0.8237               0.8298          0.8296
# 2:1                   0.8111               0.8189          0.8163
# 1:1                   0.7809               0.7930          0.7936
# 0.5:1                 0.7449               0.7704          0.7644
# 0.25:1                0.6974               0.7357          0.7356
# 0.1:1                 0.6469               0.6939          0.6969
#
#         Pubmed from Glove, length-based  Pubmed from Glove, cluster  \
# ...

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#F35361']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)

line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':']

y_error = [[0.004, 0.005, 0.003, 0.004, 0.004, 0.003, 0.003, 0.003, 0.005, 0.007, 0.006, 0.009], 
           [0.005, 0.007, 0.004, 0.003, 0.004, 0.002, 0.002, 0.005, 0.004, 0.006, 0.006, 0.013],
           [0.004, 0.004, 0.004, 0.004, 0.005, 0.003, 0.003, 0.006, 0.002, 0.008, 0.007, 0.006],
           [0.005, 0.007, 0.004, 0.005, 0.004, 0.003, 0.004, 0.002, 0.002, 0.005, 0.012, 0.009],
           [0.003, 0.005, 0.005, 0.004, 0.005, 0.004, 0.002, 0.005, 0.004, 0.004, 0.012, 0.010],
           [0.005, 0.004, 0.005, 0.003, 0.003, 0.003, 0.002, 0.005, 0.004, 0.002, 0.007, 0.005],
           [0.006, 0.006, 0.006, 0.005, 0.004, 0.006, 0.005, 0.005, 0.009, 0.006, 0.005, 0.009],
           [0.004, 0.004, 0.003, 0.002, 0.002, 0.002, 0.002, 0.004, 0.006, 0.008, 0.007, 0.005],
           [0.004, 0.005, 0.004, 0.004, 0.005, 0.007, 0.006, 0.007, 0.007, 0.005, 0.004, 0.001]]

for i in range(len(df5.columns)):
    x = df5.index
    y = df5.iloc[:, i]

    plt.errorbar(x, y, yerr = y_error[i], ecolor = colours[i], linestyle = line_styles[i], label = df5.columns[i])

plt.title(
    '\nTask 3:\nF1 score by train-test split ratio and stop-word selection method', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])


plt.savefig("Task_3_results_repeats.png", bbox_inches='tight');

# %%
df6 = pd.read_csv('./Emily exp - Per relationship scores/Per_relationship results_v2.csv', index_col=0)

# %%
df6 = df6.transpose()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#5BC0EB',  
           '#E3B505', '#F35361', '#4D4E4E']

sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', '-', '-']

for i in range(len(df6.columns)):
    col = df6.columns[i]
    plt.plot(df6.index, df6[col], linestyle = line_styles[i], label = df6.columns[i])

plt.ylim([0, 1])
plt.xticks(rotation = 45)
plt.title(
    '\nTask 2:\nPercentage correct by link category\nNo symmetric triples', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_2_results_per_relationship.png", bbox_inches='tight');

# %%
df_f1 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task1.csv', index_col=0)

# %%
df_f1 = df_f1.transpose()

df_f1.head()
# Out:
#                            Random, length-based  Glove, length-based  \
# 9:1 split, 1:1 pos:neg                   0.9104               0.9180
# 7:1 split, 1:2 pos:neg                   0.8918               0.9027
# 4:1 split, 1:4 pos:neg                   0.8402               0.8623
# 1:1 split, 1:8 pos:neg                   0.7026               0.7636
# 0.5:1 split, 1:10 pos:neg                0.6584               0.6990
#
#                            Glove, cluster  Pubmed from Glove, length-based  \
# 9:1 split, 1:1 pos:neg             0.9264                           0.9348
# 7:1 split, 1:2 pos:neg             0.9027                           0.9219
# 4:1 split, 1:4 pos:neg             0.8657                           0.8841
# 1:1 split, 1:8 pos:neg             0.7709                           0.8026
# 0.5:1 split, 1:10 pos:neg          0.7151                           0.7412
#
#                            Pubmed from Glove, cluster  \
# ...

# %%
cols = ['Random, length-based', 'Glove, length-based', 'Pubmed from Glove, length-based', 'Pubmed from scratch, length-based', 'Biowordvec, length-based', 'PubmedBERT', 'Naive classifier (Negative)']

df_f1 = df_f1[cols]
df_f1 = df_f1.set_axis(['Random', 'Glove', 'Pubmed from Glove', 'Pubmed from scratch', 'BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)
df_f1
# Out:
#                            Random   Glove  Pubmed from Glove  \
# 9:1 split, 1:1 pos:neg     0.9104  0.9180             0.9348
# 7:1 split, 1:2 pos:neg     0.8918  0.9027             0.9219
# 4:1 split, 1:4 pos:neg     0.8402  0.8623             0.8841
# 1:1 split, 1:8 pos:neg     0.7026  0.7636             0.8026
# 0.5:1 split, 1:10 pos:neg  0.6584  0.6990             0.7412
#
#                            Pubmed from scratch  BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg                  0.9358      0.9400      0.9449
# 7:1 split, 1:2 pos:neg                  0.9170      0.9140      0.9347
# 4:1 split, 1:4 pos:neg                  0.8836      0.8726      0.8920
# 1:1 split, 1:8 pos:neg                  0.7847      0.7553      0.8292
# 0.5:1 split, 1:10 pos:neg               0.7214      0.6709      0.7547
#
#                            Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                          0.3333
# 7:1 split, 1:2 pos:neg                          0.4000
# ...

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#5BC0EB', 
           '#E3B505', '#F35361', '#0F5180',
           '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', '-', '-', ':']

for i in range(len(df_f1.columns)):
    col = df_f1.columns[i]
    plt.plot(df_f1.index, df_f1[col], linestyle = line_styles[i], label = df_f1.columns[i])
    
plt.title('\n\nTask 1', fontsize = 14, fontweight = 'bold')
plt.xticks(rotation = 45)
plt.ylim(0.3, 1)
plt.ylabel("F1 score")
plt.grid(True)
plt.legend(ncol = 7, prop = {'family':'Source sans pro'}, bbox_to_anchor = [1.1, 1.15], borderaxespad = -.5);

plt.savefig("Task_1_results_splits_imbal_naive_classifier.png", bbox_inches='tight');

# %%
df_f2 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task2.csv', index_col=0)
df_f2 = df_f2.transpose()

df_f2.head()
# Out:
#                            Random, length-based  Glove, length-based  \
# 9:1 split, 1:1 pos:neg                   0.9297               0.9233
# 7:1 split, 1:2 pos:neg                   0.8963               0.9092
# 4:1 split, 1:4 pos:neg                   0.8156               0.8434
# 1:1 split, 1:8 pos:neg                   0.6728               0.7310
# 0.5:1 split, 1:10 pos:neg                0.6701               0.6938
#
#                            Glove, cluster  Pubmed from Glove, length-based  \
# 9:1 split, 1:1 pos:neg             0.9267                           0.9356
# 7:1 split, 1:2 pos:neg             0.9131                           0.9241
# 4:1 split, 1:4 pos:neg             0.8593                           0.8839
# 1:1 split, 1:8 pos:neg             0.7368                           0.7909
# 0.5:1 split, 1:10 pos:neg          0.7071                           0.7644
#
#                            Pubmed from Glove, cluster  \
# ...

# %%
cols = ['Random, length-based', 'Glove, length-based', 'Pubmed from Glove, length-based', 'Pubmed from scratch, length-based', 'Biowordvec, length-based', 'PubmedBERT', 'Naive classifier (Negative)']

df_f2 = df_f2[cols]
df_f2 = df_f2.set_axis(['Random', 'Glove', 'Pubmed from Glove', 'Pubmed from scratch', 'BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)
df_f2
# Out:
#                            Random   Glove  Pubmed from Glove  \
# 9:1 split, 1:1 pos:neg     0.9297  0.9233             0.9356
# 7:1 split, 1:2 pos:neg     0.8963  0.9092             0.9241
# 4:1 split, 1:4 pos:neg     0.8156  0.8434             0.8839
# 1:1 split, 1:8 pos:neg     0.6728  0.7310             0.7909
# 0.5:1 split, 1:10 pos:neg  0.6701  0.6938             0.7644
#
#                            Pubmed from scratch  BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg                  0.9274      0.9369      0.9635
# 7:1 split, 1:2 pos:neg                  0.9201      0.9193      0.9540
# 4:1 split, 1:4 pos:neg                  0.8712      0.8572      0.9194
# 1:1 split, 1:8 pos:neg                  0.7757      0.7103      0.8560
# 0.5:1 split, 1:10 pos:neg               0.7520      0.6661      0.8139
#
#                            Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                          0.3333
# 7:1 split, 1:2 pos:neg                          0.4000
# ...

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#5BC0EB', 
           '#E3B505', '#F35361', '#0F5180',
           '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', '-', '-', ':']

for i in range(len(df_f2.columns)):
    col = df_f2.columns[i]
    plt.plot(df_f2.index, df_f2[col], linestyle = line_styles[i], label = df_f2.columns[i])
    
plt.title('\n\nTask 2', fontsize = 14, fontweight = 'bold')
plt.xticks(rotation = 45)
plt.ylim(0.3, 1)
plt.ylabel("F1 score")
plt.grid(True)
plt.legend(ncol = 7, prop = {'family':'Source sans pro'}, bbox_to_anchor = [1.1, 1.15], borderaxespad = -.5);

plt.savefig("Task_2_results_splits_imbal_naive_classifier.png", bbox_inches='tight');

# %%
df_f3 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task3.csv', index_col=0)
df_f3 = df_f3.transpose()

df_f3.head()
# Out:
#                            Random, length-based  Glove, length-based  \
# 9:1 split, 1:1 pos:neg                   0.8559               0.8565
# 7:1 split, 1:2 pos:neg                   0.8440               0.8463
# 4:1 split, 1:4 pos:neg                   0.7784               0.7853
# 1:1 split, 1:8 pos:neg                   0.6428               0.6663
# 0.5:1 split, 1:10 pos:neg                0.6202               0.6209
#
#                            Glove, cluster  Pubmed from Glove, length-based  \
# 9:1 split, 1:1 pos:neg             0.8568                           0.8583
# 7:1 split, 1:2 pos:neg             0.8656                           0.8492
# 4:1 split, 1:4 pos:neg             0.7917                           0.7902
# 1:1 split, 1:8 pos:neg             0.6618                           0.7081
# 0.5:1 split, 1:10 pos:neg          0.6401                           0.6709
#
#                            Pubmed from Glove, cluster  \
# ...

# %%
cols = ['Random, length-based', 'Glove, length-based', 'Pubmed from Glove, length-based', 'Pubmed from scratch, length-based', 'Biowordvec, length-based', 'PubmedBERT', 'Naive classifier (Negative)']

df_f3 = df_f3[cols]
df_f3 = df_f3.set_axis(['Random', 'Glove', 'Pubmed from Glove', 'Pubmed from scratch', 'BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)
df_f3
# Out:
#                            Random   Glove  Pubmed from Glove  \
# 9:1 split, 1:1 pos:neg     0.8559  0.8565             0.8583
# 7:1 split, 1:2 pos:neg     0.8440  0.8463             0.8492
# 4:1 split, 1:4 pos:neg     0.7784  0.7853             0.7902
# 1:1 split, 1:8 pos:neg     0.6428  0.6663             0.7081
# 0.5:1 split, 1:10 pos:neg  0.6202  0.6209             0.6709
#
#                            Pubmed from scratch  BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg                  0.8609      0.8657      0.8700
# 7:1 split, 1:2 pos:neg                  0.8503      0.8517      0.8561
# 4:1 split, 1:4 pos:neg                  0.7885      0.7980      0.8078
# 1:1 split, 1:8 pos:neg                  0.7062      0.6509      0.6984
# 0.5:1 split, 1:10 pos:neg               0.6643      0.6099      0.6456
#
#                            Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                          0.3333
# 7:1 split, 1:2 pos:neg                          0.4000
# ...

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#5BC0EB', 
           '#E3B505', '#F35361', '#0F5180',
           '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', '-', '-', ':']

for i in range(len(df_f3.columns)):
    col = df_f3.columns[i]
    plt.plot(df_f3.index, df_f3[col], linestyle = line_styles[i], label = df_f3.columns[i])
    
plt.title('\n\nTask 3', fontsize = 14, fontweight = 'bold')
plt.xticks(rotation = 45)
plt.ylim(0.3, 1)
plt.ylabel("F1 score")
plt.grid(True)
plt.legend(ncol = 7, prop = {'family':'Source sans pro'}, bbox_to_anchor = [1.1, 1.15], borderaxespad = -.5);

plt.savefig("Task_3_results_splits_imbal_naive_classifier.png", bbox_inches='tight');

# %%
df7 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task3.csv', index_col=0)

# %%
df7 = df7.transpose()

df7.head()
# Out:
#                            Random, length-based  Glove, length-based  \
# 9:1 split, 1:1 pos:neg                   0.8559               0.8565
# 7:1 split, 1:2 pos:neg                   0.8440               0.8463
# 4:1 split, 1:4 pos:neg                   0.7784               0.7853
# 1:1 split, 1:8 pos:neg                   0.6428               0.6663
# 0.5:1 split, 1:10 pos:neg                0.6202               0.6209
#
#                            Glove, cluster  Pubmed from Glove, length-based  \
# 9:1 split, 1:1 pos:neg             0.8568                           0.8583
# 7:1 split, 1:2 pos:neg             0.8656                           0.8492
# 4:1 split, 1:4 pos:neg             0.7917                           0.7902
# 1:1 split, 1:8 pos:neg             0.6618                           0.7081
# 0.5:1 split, 1:10 pos:neg          0.6401                           0.6709
#
#                            Pubmed from Glove, cluster  \
# ...

# %%
cols = ['Random, length-based', 'Glove, cluster', 'Biowordvec, cluster', 'PubmedBERT', 'Naive classifier (Negative)']

df7 = df7[cols]

df7 = df7.set_axis(['RF_Random', 'RF_Glove', 'RF_BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)


df7 = df7.iloc[0:4]

df7
# Out:
#                         RF_Random  RF_Glove  RF_BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg     0.8559    0.8568         0.8547      0.8700
# 7:1 split, 1:2 pos:neg     0.8440    0.8656         0.8429      0.8561
# 4:1 split, 1:4 pos:neg     0.7784    0.7917         0.7824      0.8078
# 1:1 split, 1:8 pos:neg     0.6428    0.6618         0.6581      0.6984
#
#                         Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                       0.3333
# 7:1 split, 1:2 pos:neg                       0.4000
# 4:1 split, 1:4 pos:neg                       0.4445
# 1:1 split, 1:8 pos:neg                       0.4706

# %%
plt.figure(figsize = (10,6))

colours = ['#D1E3EA', '#8DB9CA', '#5295AF', '#366475', '#000000']
plt.style.use('default')

sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', ':']

for i in range(len(df7.columns)):
    col = df7.columns[i]
    plt.plot(df7.index, df7[col], linestyle = line_styles[i], label = df7.columns[i])
    
plt.title(
    '\nTask 3', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.ylim(0.3, 1)
plt.legend(bbox_to_anchor = [1.35, 1])

plt.savefig("Task_3_results.png", bbox_inches='tight');

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E',
           '#787979', '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-', ':', 'dashed']

for i in range(len(df7.columns)):
    col = df7.columns[i]
    plt.plot(df7.index, df7[col], linestyle = line_styles[i], label = df7.columns[i])
    
plt.title(
    '\nTask 3:\nF1 score by train-test split ratio and and ratio positive:negative data', 
    fontsize = 14, fontweight = 'bold')
plt.xticks(rotation = 45)
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_3_results_splits_imbal_naive_classifier.png", bbox_inches='tight');

# %%
cols = ['Random, length-based', 'Glove, cluster', 'Biowordvec, cluster', 'PubmedBERT', 'Naive classifier (Negative)']

df8 = df8[cols]

df8 = df8.set_axis(['RF_Random', 'RF_Glove', 'RF_BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)


df8 = df8.iloc[0:4]

df8

# %%
df8 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task2.csv', index_col=0)

# %%
df8 = df8.transpose()

# %%
cols = ['Random, length-based', 'Glove, cluster', 'Biowordvec, cluster', 'PubmedBERT', 'Naive classifier (Negative)']

df8 = df8[cols]

df8 = df8.set_axis(['RF_Random', 'RF_Glove', 'RF_BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)


df8 = df8.iloc[0:4]

df8
# Out:
#                         RF_Random  RF_Glove  RF_BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg     0.9297    0.9267         0.9290      0.9635
# 7:1 split, 1:2 pos:neg     0.8963    0.9131         0.9150      0.9540
# 4:1 split, 1:4 pos:neg     0.8156    0.8593         0.8777      0.9194
# 1:1 split, 1:8 pos:neg     0.6728    0.7368         0.7214      0.8560
#
#                         Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                       0.3333
# 7:1 split, 1:2 pos:neg                       0.4000
# 4:1 split, 1:4 pos:neg                       0.4444
# 1:1 split, 1:8 pos:neg                       0.4706

# %%
plt.figure(figsize = (10,6))

colours = ['#D1E3EA', '#8DB9CA', '#5295AF', '#366475', '#000000']
plt.style.use('default')

sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', ':']

for i in range(len(df8.columns)):
    col = df8.columns[i]
    plt.plot(df8.index, df8[col], linestyle = line_styles[i], label = df8.columns[i])
    
plt.title(
    '\nTask 2', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_2_results.png", bbox_inches='tight');

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', 
           '#E3B505', '#E3B505', '#F35361', '#F35361', '#4D4E4E',
           '#787979', '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-', ':']

for i in range(len(df8.columns)):
    col = df8.columns[i]
    plt.plot(df8.index, df8[col], linestyle = line_styles[i], label = df8.columns[i])
    
plt.title(
    '\nTask 2:\nF1 score by train-test split ratio and and ratio positive:negative data', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_2_results_splits_imbal_naive_classifier.png", bbox_inches='tight');

# %%
df9 = pd.read_csv('./Emily exp - Splits + imbalanced data/Results_Task1.csv', index_col=0)

# %%
df9 = df9.transpose()

# %%
cols = ['Random, length-based', 'Glove, cluster', 'Biowordvec, cluster', 'PubmedBERT', 'Naive classifier (Negative)']

df9 = df9[cols]

df9 = df9.set_axis(['RF_Random', 'RF_Glove', 'RF_BioWordVec', 'PubmedBERT', 'Naive classifier (Negative)'], axis=1)


df9 = df9.iloc[0:4]

df9
# Out:
#                            RF_Random  RF_Glove  RF_BioWordVec  PubmedBERT  \
# 9:1 split, 1:1 pos:neg        0.9104    0.9264         0.9319      0.9449
# 7:1 split, 1:2 pos:neg        0.8918    0.9027         0.9042      0.9347
# 4:1 split, 1:4 pos:neg        0.8402    0.8657         0.8658      0.8920
# 1:1 split, 1:8 pos:neg        0.7026    0.7709         0.7618      0.8292
# 0.5:1 split, 1:10 pos:neg     0.6584    0.7151         0.6808      0.7547
#
#                            Naive classifier (Negative)
# 9:1 split, 1:1 pos:neg                          0.3333
# 7:1 split, 1:2 pos:neg                          0.4000
# 4:1 split, 1:4 pos:neg                          0.4445
# 1:1 split, 1:8 pos:neg                          0.4706
# 0.5:1 split, 1:10 pos:neg                       0.4757

# %%
df9 = df9.iloc[0:4]

# %%
plt.figure(figsize = (10,6))

colours = ['#D1E3EA', '#8DB9CA', '#5295AF', '#366475', '#000000']
plt.style.use('default')

sns.set_palette(colours)
line_styles = ['-', '-', '-', '-', ':']

for i in range(len(df9.columns)):
    col = df9.columns[i]
    plt.plot(df9.index, df9[col], linestyle = line_styles[i], label = df9.columns[i])
    
plt.title(
    '\nTask 1', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.ylim(0.3, 1)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("Task_1_results.png", bbox_inches='tight');

# %%
df10 = pd.read_csv('./Emily exp - LSTM/Results_Task1.csv', index_col=0)

# %%
df10 = df11.transpose()

# %%
plt.figure(figsize = (10,6))

colours = ['#04A777', '#8B0462', '#5BC0EB', 
           '#E3B505', '#F35361', '#4D4E4E',
           '#787979', '#787979']
#colours = ['#04A777', '#8B0462', '#8B0462', '#5BC0EB', '#5BC0EB', '#E3B505', '#E3B505', '#F35361', '#0F5180']
sns.set_palette(colours)
line_styles = ['-', '-', ':', '-', ':', '-', ':', '-', ':', '-', ':', 'dashed']

for i in range(len(df10.columns)):
    col = df10.columns[i]
    plt.plot(df10.index, df10[col], linestyle = line_styles[i], label = df10.columns[i])
    
plt.title(
    '\nTask 1, LSTM:\nF1 score by train-test split ratio and and ratio positive:negative data', 
    fontsize = 14, fontweight = 'bold')
plt.grid(True)
plt.legend(bbox_to_anchor = [1, 1])

plt.savefig("LSTM_Task_1_results_splits_imbal_naive_classifier.png", bbox_inches='tight');
